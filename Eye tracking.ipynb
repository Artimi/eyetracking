# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %%
import eyetracking as et

# %% [markdown]
# Record is object of python with all important informations about line in csv file. We have there name of subject, known status, and all positions

# %%
records = []
for rec in et.get_record():
    records.append(rec)
    r = rec
    break

# %%
plt.scatter(r.position[0,:], r.position[1, :], s=1)
plt.annotate('start', xy=r.position[:, 0], xytext=r.position[:, 0] + 50, arrowprops=dict(facecolor='black'))
plt.annotate('end', xy=r.position[:, -1], xytext=r.position[:, -1] + 50, arrowprops=dict(facecolor='black'))
plt.gca().invert_yaxis()

# %% [markdown]
# Here we plot computed velocity and in red is marked parts that are considered as peaks.

# %%
peaks = np.ma.masked_array(r.velocity,np.logical_not(r.peaks))
fixations = np.ma.masked_array(r.velocity,r.peaks)
plot(peaks, 'r-', fixations, 'b-')
# Out:
# [<matplotlib.lines.Line2D at 0xd1946d0>,
#  <matplotlib.lines.Line2D at 0xd194910>]

# %% [markdown]
# MSA and MFD coefficients of this record.

# %%
r.MSA
# Out:
# 17.468391449679199

# %%
r.MFD
# Out:
# 229.0

# %% [markdown]
# Array of length of fixations. Fixations shorter than 10 are discarded from computation of MFD.

# %%
r.len_fixations
# Out:
# array([   1.,  267.,  303.,  147.,    2.,  226.,    1.,  203.,  142.,
#           7.,   10.,    1.,    2.,  120.,  256.,  249.,  304.,  242.,
#           1.,    2.,  236.,  282.])

# %% [markdown]
# Example how getting results work

# %%
rd = et.get_result_dict()

# %%
results = et.process_result(rd)

# %%
import pprint
pprint.pprint(rd['s1'])
# Out:
# {'false': {'MFD': array([ 229.        ,  216.71428571,  237.33333333,  238.875     ,
#         246.85714286,  314.2       ,  261.5       ]),
#            'MSA': array([ 17.51599119,  15.76700665,  17.64317399,  21.27974571,
#         19.29611759,  18.67573855,  24.35399524])},
#  'true': {'MFD': array([ 296.125     ,  272.8       ,  278.        ,  348.28571429]),
#           'MSA': array([ 17.16986484,  25.83526406,  20.68129526,  18.26070699])}}
